# %%
#importing all packages needed
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#loading and inspecting dataset
df = pd.read_csv('tmdb_5000_movies.csv')
df.head(5)
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
# 3  [{"id": 849, "name": "dc comics"}, {"id": 853,...                en
# 4  [{"id": 818, "name": "based on novel"}, {"id":...                en
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                             overview  popularity  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615
# 2  A cryptic message from Bond’s past sends him o...  107.376788
# 3  Following the death of District Attorney Harve...  112.312950
# 4  John Carter is a war-weary, former military ca...   43.926995
#
#                                 production_companies  \
# 0  [{"name": "Ingenious Film Partners", "id": 289...
# 1  [{"name": "Walt Disney Pictures", "id": 2}, {"...
# 2  [{"name": "Columbia Pictures", "id": 5}, {"nam...
# 3  [{"name": "Legendary Pictures", "id": 923}, {"...
# 4        [{"name": "Walt Disney Pictures", "id": 2}]
#
#                                 production_countries release_date     revenue  \
# 0  [{"iso_3166_1": "US", "name": "United States o...   2009-12-10  2787965087
# 1  [{"iso_3166_1": "US", "name": "United States o...   2007-05-19   961000000
# 2  [{"iso_3166_1": "GB", "name": "United Kingdom"...   2015-10-26   880674609
# 3  [{"iso_3166_1": "US", "name": "United States o...   2012-07-16  1084939099
# 4  [{"iso_3166_1": "US", "name": "United States o...   2012-03-07   284139100
#
#    runtime                                   spoken_languages    status  \
# 0    162.0  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 1    169.0           [{"iso_639_1": "en", "name": "English"}]  Released
# 2    148.0  [{"iso_639_1": "fr", "name": "Fran\u00e7ais"},...  Released
# 3    165.0           [{"iso_639_1": "en", "name": "English"}]  Released
# 4    132.0           [{"iso_639_1": "en", "name": "English"}]  Released
#
#                                           tagline  \
# 0                     Enter the World of Pandora.
# 1  At the end of the world, the adventure begins.
# 2                           A Plan No One Escapes
# 3                                 The Legend Ends
# 4            Lost in our world, found in another.
#
#                                       title  vote_average  vote_count
# 0                                    Avatar           7.2       11800
# 1  Pirates of the Caribbean: At World's End           6.9        4500
# 2                                   Spectre           6.3        4466
# 3                     The Dark Knight Rises           7.6        9106
# 4                               John Carter           6.1        2124

# %%
#printing concised summary of the report
df.describe()
# Out:
#              budget             id   popularity       revenue      runtime  \
# count  4.803000e+03    4803.000000  4803.000000  4.803000e+03  4801.000000
# mean   2.904504e+07   57165.484281    21.492301  8.226064e+07   106.875859
# std    4.072239e+07   88694.614033    31.816650  1.628571e+08    22.611935
# min    0.000000e+00       5.000000     0.000000  0.000000e+00     0.000000
# 25%    7.900000e+05    9014.500000     4.668070  0.000000e+00    94.000000
# 50%    1.500000e+07   14629.000000    12.921594  1.917000e+07   103.000000
# 75%    4.000000e+07   58610.500000    28.313505  9.291719e+07   118.000000
# max    3.800000e+08  459488.000000   875.581305  2.787965e+09   338.000000
#
#        vote_average    vote_count
# count   4803.000000   4803.000000
# mean       6.092172    690.217989
# std        1.194612   1234.585891
# min        0.000000      0.000000
# 25%        5.600000     54.000000
# 50%        6.200000    235.000000
# 75%        6.800000    737.000000
# max       10.000000  13752.000000

# %%
df.shape
# Out:
# (4803, 20)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4803 entries, 0 to 4802
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   budget                4803 non-null   int64
#  1   genres                4803 non-null   object
#  2   homepage              1712 non-null   object
#  3   id                    4803 non-null   int64
#  4   keywords              4803 non-null   object
#  5   original_language     4803 non-null   object
#  6   original_title        4803 non-null   object
#  7   overview              4800 non-null   object
#  8   popularity            4803 non-null   float64
#  9   production_companies  4803 non-null   object
#  10  production_countries  4803 non-null   object
#  11  release_date          4802 non-null   object
#  12  revenue               4803 non-null   int64
#  13  runtime               4801 non-null   float64
#  14  spoken_languages      4803 non-null   object
#  15  status                4803 non-null   object
#  16  tagline               3959 non-null   object
#  17  title                 4803 non-null   object
#  18  vote_average          4803 non-null   float64
#  19  vote_count            4803 non-null   int64
# dtypes: float64(3), int64(4), object(13)
# memory usage: 750.6+ KB

# %% [markdown]
# Data Cleaning
#
# 1:Deleting columns that are not required.
# 2:Handling zero values
# 3:Checking and droping Null values.
# 4:Checking and Removing duplicates.
# 5:Changing the format of release date into DateTime format.
# 6:Handling columns with pipes
# 7:Checking datatype of columns

# %%
#Lets drop columns that are not needed for this analysis 
#Dropping columns such as imdb_id as there is already a unique identifier "id". Droping tagline, keywords, overview and homepage as well.
drop_list= [ 'tagline', 'keywords', 'overview', 'homepage','spoken_languages' ]
df.drop(drop_list, axis = 1, inplace = True)

# %%
df.head()
# Out:
#       budget                                             genres      id  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...   19995
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...     285
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...  206647
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...   49026
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...   49529
#
#   original_language                            original_title  popularity  \
# 0                en                                    Avatar  150.437577
# 1                en  Pirates of the Caribbean: At World's End  139.082615
# 2                en                                   Spectre  107.376788
# 3                en                     The Dark Knight Rises  112.312950
# 4                en                               John Carter   43.926995
#
#                                 production_companies  \
# 0  [{"name": "Ingenious Film Partners", "id": 289...
# 1  [{"name": "Walt Disney Pictures", "id": 2}, {"...
# 2  [{"name": "Columbia Pictures", "id": 5}, {"nam...
# 3  [{"name": "Legendary Pictures", "id": 923}, {"...
# 4        [{"name": "Walt Disney Pictures", "id": 2}]
#
#                                 production_countries release_date     revenue  \
# 0  [{"iso_3166_1": "US", "name": "United States o...   2009-12-10  2787965087
# 1  [{"iso_3166_1": "US", "name": "United States o...   2007-05-19   961000000
# 2  [{"iso_3166_1": "GB", "name": "United Kingdom"...   2015-10-26   880674609
# 3  [{"iso_3166_1": "US", "name": "United States o...   2012-07-16  1084939099
# 4  [{"iso_3166_1": "US", "name": "United States o...   2012-03-07   284139100
#
#    runtime    status                                     title  vote_average  \
# 0    162.0  Released                                    Avatar           7.2
# 1    169.0  Released  Pirates of the Caribbean: At World's End           6.9
# 2    148.0  Released                                   Spectre           6.3
# 3    165.0  Released                     The Dark Knight Rises           7.6
# 4    132.0  Released                               John Carter           6.1
#
#    vote_count
# 0       11800
# 1        4500
# 2        4466
# 3        9106
# 4        2124

# %%
df.shape
# Out:
# (4803, 15)

# %%
#Checking revenue, budget and runtime column rows for Zero values
zero_values= df.query('revenue == 0 or budget ==0 or runtime ==0 or popularity ==0 or vote_average ==0 or vote_count ==0')
zero_values.head()
# Out:
#         budget                                             genres     id  \
# 83    27000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...  79698
# 135  150000000  [{"id": 18, "name": "Drama"}, {"id": 27, "name...   7978
# 265          0  [{"id": 35, "name": "Comedy"}, {"id": 14, "nam...  10588
# 309   84000000  [{"id": 14, "name": "Fantasy"}, {"id": 35, "na...  10214
# 321          0                     [{"id": 35, "name": "Comedy"}]  77953
#
#     original_language      original_title  popularity  \
# 83                 en          The Lovers    2.418535
# 135                en         The Wolfman   21.214571
# 265                en  The Cat in the Hat   18.251129
# 309                en     Son of the Mask   17.815595
# 321                en        The Campaign   16.460356
#
#                                   production_companies  \
# 83   [{"name": "Corsan", "id": 7299}, {"name": "Bli...
# 135  [{"name": "Universal Pictures", "id": 33}, {"n...
# 265  [{"name": "Imagine Entertainment", "id": 23}, ...
# 309  [{"name": "New Line Cinema", "id": 12}, {"name...
# 321  [{"name": "Everyman Pictures", "id": 2242}, {"...
#
#                                   production_countries release_date  \
# 83   [{"iso_3166_1": "AU", "name": "Australia"}, {"...   2015-02-13
# 135  [{"iso_3166_1": "US", "name": "United States o...   2010-02-11
# 265  [{"iso_3166_1": "US", "name": "United States o...   2003-11-21
# 309  [{"iso_3166_1": "DE", "name": "Germany"}, {"is...   2005-02-18
# 321  [{"iso_3166_1": "US", "name": "United States o...   2012-08-09
#
#        revenue  runtime    status               title  vote_average  \
# 83           0    109.0  Released          The Lovers           4.8
# 135          0    102.0  Released         The Wolfman           5.5
# 265          0     82.0  Released  The Cat in the Hat           4.9
# 309          0     94.0  Released     Son of the Mask           3.6
# 321  104907746     85.0  Released        The Campaign           5.6
#
#      vote_count
# 83           34
# 135         549
# 265         366
# 309         338
# 321         578

# %%
zero_values.shape
# Out:
# (1576, 15)

# %%
#replacing the zero values with NAN.

df['revenue'].replace(0, np.NAN, inplace=True)
df['budget'].replace(0, np.NAN, inplace=True)
df['popularity'].replace(0, np.NAN, inplace=True)
df['vote_average'].replace(0, np.NAN, inplace=True)
df['vote_count'].replace(0, np.NAN, inplace=True)
df['runtime'].replace(0, np.NAN, inplace=True)

# %%
#total null values in each column in the dataset
df.isna().sum()
# Out:
# budget                  1037
# genres                     0
# id                         0
# original_language          0
# original_title             0
# popularity                 1
# production_companies       0
# production_countries       0
# release_date               1
# revenue                 1427
# runtime                   37
# status                     0
# title                      0
# vote_average              63
# vote_count                62
# dtype: int64

# %%
#Dropping null values
df.dropna(inplace = True)

df.isna().sum().sum()
# Out:
# 0

# %%
#Checking for duplicates
sum(df.duplicated())
# Out:
# 0

# %%
#Shape of new dataframe
df.shape
# Out:
# (3227, 15)

# %%
#Changing format of release date to datetime format
df['release_date']= pd.to_datetime(df['release_date'])

# %%
df.head()
# Out:
#         budget                                             genres      id  \
# 0  237000000.0  [{"id": 28, "name": "Action"}, {"id": 12, "nam...   19995
# 1  300000000.0  [{"id": 12, "name": "Adventure"}, {"id": 14, "...     285
# 2  245000000.0  [{"id": 28, "name": "Action"}, {"id": 12, "nam...  206647
# 3  250000000.0  [{"id": 28, "name": "Action"}, {"id": 80, "nam...   49026
# 4  260000000.0  [{"id": 28, "name": "Action"}, {"id": 12, "nam...   49529
#
#   original_language                            original_title  popularity  \
# 0                en                                    Avatar  150.437577
# 1                en  Pirates of the Caribbean: At World's End  139.082615
# 2                en                                   Spectre  107.376788
# 3                en                     The Dark Knight Rises  112.312950
# 4                en                               John Carter   43.926995
#
#                                 production_companies  \
# 0  [{"name": "Ingenious Film Partners", "id": 289...
# 1  [{"name": "Walt Disney Pictures", "id": 2}, {"...
# 2  [{"name": "Columbia Pictures", "id": 5}, {"nam...
# 3  [{"name": "Legendary Pictures", "id": 923}, {"...
# 4        [{"name": "Walt Disney Pictures", "id": 2}]
#
#                                 production_countries release_date  \
# 0  [{"iso_3166_1": "US", "name": "United States o...   2009-12-10
# 1  [{"iso_3166_1": "US", "name": "United States o...   2007-05-19
# 2  [{"iso_3166_1": "GB", "name": "United Kingdom"...   2015-10-26
# 3  [{"iso_3166_1": "US", "name": "United States o...   2012-07-16
# 4  [{"iso_3166_1": "US", "name": "United States o...   2012-03-07
#
#         revenue  runtime    status                                     title  \
# 0  2.787965e+09    162.0  Released                                    Avatar
# 1  9.610000e+08    169.0  Released  Pirates of the Caribbean: At World's End
# 2  8.806746e+08    148.0  Released                                   Spectre
# 3  1.084939e+09    165.0  Released                     The Dark Knight Rises
# 4  2.841391e+08    132.0  Released                               John Carter
#
#    vote_average  vote_count
# 0           7.2     11800.0
# 1           6.9      4500.0
# 2           6.3      4466.0
# 3           7.6      9106.0
# 4           6.1      2124.0

# %%
df2= pd.read_csv('tmdb_5000_credits.csv')
df2.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# 4  [{"credit_id": "52fe479ac3a36847f813eaa3", "de...

# %%
df2.describe(include= 'all')
# Out:
#              movie_id     title  cast  crew
# count     4803.000000      4803  4803  4803
# unique            NaN      4800  4761  4776
# top               NaN  The Host    []    []
# freq              NaN         2    43    28
# mean     57165.484281       NaN   NaN   NaN
# std      88694.614033       NaN   NaN   NaN
# min          5.000000       NaN   NaN   NaN
# 25%       9014.500000       NaN   NaN   NaN
# 50%      14629.000000       NaN   NaN   NaN
# 75%      58610.500000       NaN   NaN   NaN
# max     459488.000000       NaN   NaN   NaN

# %%
df2.isna().sum()
# Out:
# movie_id    0
# title       0
# cast        0
# crew        0
# dtype: int64

# %%
df3 = pd.merge(df,df2, left_on="id", right_on="movie_id")
df3.head()
# Out:
#         budget                                             genres      id  \
# 0  237000000.0  [{"id": 28, "name": "Action"}, {"id": 12, "nam...   19995
# 1  300000000.0  [{"id": 12, "name": "Adventure"}, {"id": 14, "...     285
# 2  245000000.0  [{"id": 28, "name": "Action"}, {"id": 12, "nam...  206647
# 3  250000000.0  [{"id": 28, "name": "Action"}, {"id": 80, "nam...   49026
# 4  260000000.0  [{"id": 28, "name": "Action"}, {"id": 12, "nam...   49529
#
#   original_language                            original_title  popularity  \
# 0                en                                    Avatar  150.437577
# 1                en  Pirates of the Caribbean: At World's End  139.082615
# 2                en                                   Spectre  107.376788
# 3                en                     The Dark Knight Rises  112.312950
# 4                en                               John Carter   43.926995
#
#                                 production_companies  \
# 0  [{"name": "Ingenious Film Partners", "id": 289...
# 1  [{"name": "Walt Disney Pictures", "id": 2}, {"...
# 2  [{"name": "Columbia Pictures", "id": 5}, {"nam...
# 3  [{"name": "Legendary Pictures", "id": 923}, {"...
# 4        [{"name": "Walt Disney Pictures", "id": 2}]
#
#                                 production_countries release_date  \
# 0  [{"iso_3166_1": "US", "name": "United States o...   2009-12-10
# 1  [{"iso_3166_1": "US", "name": "United States o...   2007-05-19
# 2  [{"iso_3166_1": "GB", "name": "United Kingdom"...   2015-10-26
# 3  [{"iso_3166_1": "US", "name": "United States o...   2012-07-16
# 4  [{"iso_3166_1": "US", "name": "United States o...   2012-03-07
#
#         revenue  runtime    status                                   title_x  \
# 0  2.787965e+09    162.0  Released                                    Avatar
# 1  9.610000e+08    169.0  Released  Pirates of the Caribbean: At World's End
# 2  8.806746e+08    148.0  Released                                   Spectre
# 3  1.084939e+09    165.0  Released                     The Dark Knight Rises
# 4  2.841391e+08    132.0  Released                               John Carter
#
#    vote_average  vote_count  movie_id  \
# 0           7.2     11800.0     19995
# 1           6.9      4500.0       285
# 2           6.3      4466.0    206647
# 3           7.6      9106.0     49026
# 4           6.1      2124.0     49529
#
#                                     title_y  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# 4  [{"credit_id": "52fe479ac3a36847f813eaa3", "de...

# %%
df3.drop(['crew', 'title_y','movie_id'], axis= 1, inplace = True)

# %%
df3.head()
# Out:
#         budget                                             genres      id  \
# 0  237000000.0  [{"id": 28, "name": "Action"}, {"id": 12, "nam...   19995
# 1  300000000.0  [{"id": 12, "name": "Adventure"}, {"id": 14, "...     285
# 2  245000000.0  [{"id": 28, "name": "Action"}, {"id": 12, "nam...  206647
# 3  250000000.0  [{"id": 28, "name": "Action"}, {"id": 80, "nam...   49026
# 4  260000000.0  [{"id": 28, "name": "Action"}, {"id": 12, "nam...   49529
#
#   original_language                            original_title  popularity  \
# 0                en                                    Avatar  150.437577
# 1                en  Pirates of the Caribbean: At World's End  139.082615
# 2                en                                   Spectre  107.376788
# 3                en                     The Dark Knight Rises  112.312950
# 4                en                               John Carter   43.926995
#
#                                 production_companies  \
# 0  [{"name": "Ingenious Film Partners", "id": 289...
# 1  [{"name": "Walt Disney Pictures", "id": 2}, {"...
# 2  [{"name": "Columbia Pictures", "id": 5}, {"nam...
# 3  [{"name": "Legendary Pictures", "id": 923}, {"...
# 4        [{"name": "Walt Disney Pictures", "id": 2}]
#
#                                 production_countries release_date  \
# 0  [{"iso_3166_1": "US", "name": "United States o...   2009-12-10
# 1  [{"iso_3166_1": "US", "name": "United States o...   2007-05-19
# 2  [{"iso_3166_1": "GB", "name": "United Kingdom"...   2015-10-26
# 3  [{"iso_3166_1": "US", "name": "United States o...   2012-07-16
# 4  [{"iso_3166_1": "US", "name": "United States o...   2012-03-07
#
#         revenue  runtime    status                                   title_x  \
# 0  2.787965e+09    162.0  Released                                    Avatar
# 1  9.610000e+08    169.0  Released  Pirates of the Caribbean: At World's End
# 2  8.806746e+08    148.0  Released                                   Spectre
# 3  1.084939e+09    165.0  Released                     The Dark Knight Rises
# 4  2.841391e+08    132.0  Released                               John Carter
#
#    vote_average  vote_count                                               cast
# 0           7.2     11800.0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1           6.9      4500.0  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2           6.3      4466.0  [{"cast_id": 1, "character": "James Bond", "cr...
# 3           7.6      9106.0  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4           6.1      2124.0  [{"cast_id": 5, "character": "John Carter", "c...

# %%
df_pc = pd.DataFrame(df3['genres'])

# %%
import ast
def convert(text):
    L=[]
    for i in ast.literal_eval(text):
        L.append(i['name'])
    return L

# %%
df3['genres']=df3['genres'].apply(convert)

# %%
df3.head()
# Out:
#         budget                                         genres      id  \
# 0  237000000.0  [Action, Adventure, Fantasy, Science Fiction]   19995
# 1  300000000.0                   [Adventure, Fantasy, Action]     285
# 2  245000000.0                     [Action, Adventure, Crime]  206647
# 3  250000000.0               [Action, Crime, Drama, Thriller]   49026
# 4  260000000.0           [Action, Adventure, Science Fiction]   49529
#
#   original_language                            original_title  popularity  \
# 0                en                                    Avatar  150.437577
# 1                en  Pirates of the Caribbean: At World's End  139.082615
# 2                en                                   Spectre  107.376788
# 3                en                     The Dark Knight Rises  112.312950
# 4                en                               John Carter   43.926995
#
#                                 production_companies  \
# 0  [{"name": "Ingenious Film Partners", "id": 289...
# 1  [{"name": "Walt Disney Pictures", "id": 2}, {"...
# 2  [{"name": "Columbia Pictures", "id": 5}, {"nam...
# 3  [{"name": "Legendary Pictures", "id": 923}, {"...
# 4        [{"name": "Walt Disney Pictures", "id": 2}]
#
#                                 production_countries release_date  \
# 0  [{"iso_3166_1": "US", "name": "United States o...   2009-12-10
# 1  [{"iso_3166_1": "US", "name": "United States o...   2007-05-19
# 2  [{"iso_3166_1": "GB", "name": "United Kingdom"...   2015-10-26
# 3  [{"iso_3166_1": "US", "name": "United States o...   2012-07-16
# 4  [{"iso_3166_1": "US", "name": "United States o...   2012-03-07
#
#         revenue  runtime    status                                   title_x  \
# 0  2.787965e+09    162.0  Released                                    Avatar
# 1  9.610000e+08    169.0  Released  Pirates of the Caribbean: At World's End
# 2  8.806746e+08    148.0  Released                                   Spectre
# 3  1.084939e+09    165.0  Released                     The Dark Knight Rises
# 4  2.841391e+08    132.0  Released                               John Carter
#
#    vote_average  vote_count                                               cast
# 0           7.2     11800.0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1           6.9      4500.0  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2           6.3      4466.0  [{"cast_id": 1, "character": "James Bond", "cr...
# 3           7.6      9106.0  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4           6.1      2124.0  [{"cast_id": 5, "character": "John Carter", "c...

# %%
#Separating columns with pipe | into different columns
#Columns such as cast, director, genres and production_companies
df3['production_companies']=df3['production_companies'].apply(convert)
df3['cast']=df3['cast'].apply(convert)
df3['production_countries']=df3['production_countries'].apply(convert)

# %%
df3.head()
# Out:
#         budget                                         genres      id  \
# 0  237000000.0  [Action, Adventure, Fantasy, Science Fiction]   19995
# 1  300000000.0                   [Adventure, Fantasy, Action]     285
# 2  245000000.0                     [Action, Adventure, Crime]  206647
# 3  250000000.0               [Action, Crime, Drama, Thriller]   49026
# 4  260000000.0           [Action, Adventure, Science Fiction]   49529
#
#   original_language                            original_title  popularity  \
# 0                en                                    Avatar  150.437577
# 1                en  Pirates of the Caribbean: At World's End  139.082615
# 2                en                                   Spectre  107.376788
# 3                en                     The Dark Knight Rises  112.312950
# 4                en                               John Carter   43.926995
#
#                                 production_companies  \
# 0  [Ingenious Film Partners, Twentieth Century Fo...
# 1  [Walt Disney Pictures, Jerry Bruckheimer Films...
# 2                   [Columbia Pictures, Danjaq, B24]
# 3  [Legendary Pictures, Warner Bros., DC Entertai...
# 4                             [Walt Disney Pictures]
#
#                          production_countries release_date       revenue  \
# 0  [United States of America, United Kingdom]   2009-12-10  2.787965e+09
# 1                  [United States of America]   2007-05-19  9.610000e+08
# 2  [United Kingdom, United States of America]   2015-10-26  8.806746e+08
# 3                  [United States of America]   2012-07-16  1.084939e+09
# 4                  [United States of America]   2012-03-07  2.841391e+08
#
#    runtime    status                                   title_x  vote_average  \
# 0    162.0  Released                                    Avatar           7.2
# 1    169.0  Released  Pirates of the Caribbean: At World's End           6.9
# 2    148.0  Released                                   Spectre           6.3
# 3    165.0  Released                     The Dark Knight Rises           7.6
# 4    132.0  Released                               John Carter           6.1
#
#    vote_count                                               cast
# 0     11800.0  [Sam Worthington, Zoe Saldana, Sigourney Weave...
# 1      4500.0  [Johnny Depp, Orlando Bloom, Keira Knightley, ...
# 2      4466.0  [Daniel Craig, Christoph Waltz, Léa Seydoux, R...
# 3      9106.0  [Christian Bale, Michael Caine, Gary Oldman, A...
# 4      2124.0  [Taylor Kitsch, Lynn Collins, Samantha Morton,...

# %%
#Checking if all columns contain the intended data type
df3.dtypes
# Out:
# budget                         float64
# genres                          object
# id                               int64
# original_language               object
# original_title                  object
# popularity                     float64
# production_companies            object
# production_countries            object
# release_date            datetime64[ns]
# revenue                        float64
# runtime                        float64
# status                          object
# title_x                         object
# vote_average                   float64
# vote_count                     float64
# cast                            object
# dtype: object

# %%
dff= df3.copy()

# %%
dff.shape
# Out:
# (3227, 16)

# %%
df3.shape
# Out:
# (3227, 16)

# %%
#viewing the distribution of some of the columns
dff.hist(figsize=(10,8));

# %% [markdown]
# Exploratory Data Analysis
# Question 1: ("How did the amount of released movies change over time?)

# %%
#Which year has the highest release of movies?
movies_year = dff.groupby(dff.release_date.dt.year).id.count()

# %%
movies_year.sort_values()
# Out:
# release_date
# 1916      1
# 1950      1
# 1947      1
# 1958      1
# 1941      1
#        ...
# 2013    152
# 2009    154
# 2010    162
# 2006    163
# 2011    168
# Name: id, Length: 89, dtype: int64

# %%
#Using a line graph to visualize how the amount of produced movies have changed over the years.
movies_year.plot(kind = 'line', figsize= (10,8),xticks = np.arange(1916,2017,10))

#setting graph labels
plt.title('Number of Released movies by Year')
plt.xlabel('Year')
plt.ylabel('Number of Realeased movies');

# %% [markdown]
# Question 2: Which Month Released Highest Number Of Movies In All Of The Years?

# %%
#Creating a new column called month from the released date
movies_month = dff.groupby(dff.release_date.dt.month).id.count()
movies_month.sort_values()
# Out:
# release_date
# 1     192
# 4     221
# 2     226
# 3     238
# 5     245
# 11    255
# 7     263
# 8     283
# 6     291
# 10    291
# 12    336
# 9     386
# Name: id, dtype: int64

# %%
#plotting a bar chart to show months and the number of movies 
movies_month.plot(x='month',kind='bar',fontsize = 11,figsize=(8,6))
#setting the labels and titles of the plot.
plt.title('Months vs Number Of Movie Releases',fontsize = 15)
plt.xlabel('Month',fontsize = 13)
plt.ylabel('Number of movie releases',fontsize = 13)
sns.set_style("darkgrid")

# %% [markdown]
# Question 3: What is the Most and least popular movie?

# %%
#defining a funct 'Minmax' using the functions 'idmin' and 'idmax' to find the index of lowest popularity and index of Highest popularity.
'''
    The function prints the row related to the index.
'''
def Minmax(x):
    #using function 'idmin' to find the index of lowest popularity.
    min_index = dff[x].idxmin()
    #using function 'idmax' to find the index of Highest popularity.
    max_index = dff[x].idxmax()
    maxi = pd.DataFrame(dff.loc[max_index,:])
    mini = pd.DataFrame(dff.loc[min_index,:])
    
    #print the movie with high and low popularity
    print("The movie with the highest "+ x + " : ",dff['original_title'][max_index])
    print("The movie with the lowest "+ x + "  : ",dff['original_title'][min_index])
    #return the rows and drop any row with NaN value
    return pd.concat([maxi,mini],axis = 1).dropna()
    

#call the Minmax function.
Minmax('popularity')
# Out:
# The movie with the highest popularity :  Minions
# The movie with the lowest popularity  :  Woman Thou Art Loosed
#                                                                    525   \
# budget                                                       74000000.0
# genres                           [Family, Animation, Adventure, Comedy]
# id                                                               211672
# original_language                                                    en
# original_title                                                  Minions
# popularity                                                   875.581305
# production_companies   [Universal Pictures, Illumination Entertainment]
# production_countries                         [United States of America]
# release_date                                        2015-06-17 00:00:00
# revenue                                                    1156730962.0
# runtime                                                            91.0
# status                                                         Released
# title_x                                                         Minions
# vote_average                                                        6.4
# vote_count                                                       4571.0
# cast                  [Sandra Bullock, Jon Hamm, Michael Keaton, All...
#
#                                                                    2946
# budget                                                        3000000.0
# genres                                                          [Drama]
# id                                                                44634
# original_language                                                    en
# original_title                                    Woman Thou Art Loosed
# popularity                                                     0.019984
# production_companies                                                 []
# production_countries                         [United States of America]
# release_date                                        2004-09-30 00:00:00
# revenue                                                       6804016.0
# runtime                                                            94.0
# status                                                         Released
# title_x                                           Woman Thou Art Loosed
# vote_average                                                        5.0
# vote_count                                                          3.0
# cast                  [Kimberly Elise, Loretta Devine, Debbi Morgan,...

# %% [markdown]
# Question 4: What are the 10 most and least profitable movies?

# %%
#Adding a new column 'Profit'
dff['Profit']= dff['revenue']-dff['budget']

# %%
dff.head(1)
# Out:
#         budget                                         genres     id  \
# 0  237000000.0  [Action, Adventure, Fantasy, Science Fiction]  19995
#
#   original_language original_title  popularity  \
# 0                en         Avatar  150.437577
#
#                                 production_companies  \
# 0  [Ingenious Film Partners, Twentieth Century Fo...
#
#                          production_countries release_date       revenue  \
# 0  [United States of America, United Kingdom]   2009-12-10  2.787965e+09
#
#    runtime    status title_x  vote_average  vote_count  \
# 0    162.0  Released  Avatar           7.2     11800.0
#
#                                                 cast        Profit
# 0  [Sam Worthington, Zoe Saldana, Sigourney Weave...  2.550965e+09

# %%
#sorting the 'Profit' column in decending order and store it in a new dataframe,
profit_df= pd.DataFrame(dff['Profit'].sort_values(ascending= False))

# %%
#creating new column 'original_title' in the new dataframe from the original dataframe
profit_df['original_title'] = dff['original_title']
#x = list(map(str,(profit_df['original_title'])))
x = list(profit_df['original_title'])
x = list(x[:10])
y = list(profit_df['Profit'][:10])

#make a plot using pointplot for top 10 profitable movies.
ax = sns.pointplot(x=y,y=x)

#setup the figure size
sns.set(rc={'figure.figsize':(8,5)})
#setup the title and labels of the plot.
ax.set_title("Top 10 Profitable Movies",fontsize = 15)
ax.set_xlabel("Profit",fontsize = 13);

# %%
#sorting the 'Profit' column in decending order and store it in a new dataframe,
profit_df= pd.DataFrame(dff['Profit'].sort_values(ascending= True))
#creating new column 'original_title' in the new dataframe from the original dataframe
profit_df['original_title'] = dff['original_title']
#x = list(map(str,(profit_df['original_title'])))
x = list(profit_df['original_title'])
x = list(x[:10])
y = list(profit_df['Profit'][:10])

#make a plot using pointplot for top 10 profitable movies.
ax = sns.pointplot(x=y,y=x)

#setup the figure size
sns.set(rc={'figure.figsize':(8,5)})
#setup the title and labels of the plot.
ax.set_title("Least 10 Profitable Movies",fontsize = 15)
ax.set_xlabel("Profit",fontsize = 13);

# %%
print(list(profit_df['original_title'].tail(10)))
# Out:
# ['Iron Man 3', 'The Lord of the Rings: The Return of the King', 'Minions', 'Frozen', 'Avengers: Age of Ultron', 'The Avengers', 'Furious 7', 'Jurassic World', 'Titanic', 'Avatar']

# %%
#using the previously defined Minmax function that pulls the minimum and maximum values to view information on the least and most profitable movie
Minmax('Profit')
# Out:
# The movie with the highest Profit :  Avatar
# The movie with the lowest Profit  :  The Lone Ranger
#                                                                      0   \
# budget                                                      237000000.0
# genres                    [Action, Adventure, Fantasy, Science Fiction]
# id                                                                19995
# original_language                                                    en
# original_title                                                   Avatar
# popularity                                                   150.437577
# production_companies  [Ingenious Film Partners, Twentieth Century Fo...
# production_countries         [United States of America, United Kingdom]
# release_date                                        2009-12-10 00:00:00
# revenue                                                    2787965087.0
# runtime                                                           162.0
# status                                                         Released
# title_x                                                          Avatar
# vote_average                                                        7.2
# vote_count                                                      11800.0
# cast                  [Sam Worthington, Zoe Saldana, Sigourney Weave...
# Profit                                                     2550965087.0
#
#                                                                      13
# budget                                                      255000000.0
# genres                                     [Action, Adventure, Western]
# id                                                                57201
# original_language                                                    en
# original_title                                          The Lone Ranger
# popularity                                                    49.046956
# production_companies  [Walt Disney Pictures, Jerry Bruckheimer Films...
# production_countries                         [United States of America]
# release_date                                        2013-07-03 00:00:00
# revenue                                                      89289910.0
# runtime                                                           149.0
# status                                                         Released
# title_x                                                 The Lone Ranger
# vote_average                                                        5.9
# vote_count                                                       2311.0
# cast                  [Johnny Depp, Armie Hammer, William Fichtner, ...
# Profit                                                     -165710090.0

# %% [markdown]
# Question 5: What are the correlations between popularity, revenue, budget and profit?

# %%
#using a scatter plot to show correlation between popularity and Revenue
x= dff['popularity']
y= dff['revenue']
plt.scatter(x,y);

# setting title labels and fontsize
plt.title('Correlation Between Popularity and Revenue', fontsize = 15)
plt.xlabel('Popularity', fontsize = 12)
plt.ylabel('Revenue', fontsize = 12);

# %%
#using scatter plot to show correlation between the movie's profit, budget and revenue
w= dff['Profit']
x= dff['budget']
y= dff['revenue']

fig = plt.figure()
#setting position of plots
ax1 = fig.add_subplot(121)
ax2 = fig.add_subplot(122)

ax1.scatter(w,x)
ax2.scatter(w,y)

#setting titles, labels and fontsize
ax1.set_title('Correlation Between the Profit and budget', fontsize = 11)
ax1.set_xlabel('profit')
ax1.set_ylabel('budget')

ax2.set_title('Correlation Between the Profit and revenue', fontsize = 11)
ax2.set_xlabel('profit')
ax2.set_ylabel('revenue');

# %%
#using scatter plot to show correlation between the movie's popularity, budget and profit
w= dff['popularity']
x= dff['budget']
y= dff['Profit']

#setting position of plots
fig = plt.figure()
ax1 = fig.add_subplot(121)
ax2 = fig.add_subplot(122)

ax1.scatter(w,x)
ax2.scatter(w,y)

#setting titles, labels and fontsize
ax1.set_title('Correlation Between Popularity and budget', fontsize = 11)
ax1.set_xlabel('popularity')
ax1.set_ylabel('budget')

ax2.set_title('Correlation Between Popularity and profit', fontsize = 11)
ax2.set_xlabel('popularity')
ax2.set_ylabel('profit');

# %% [markdown]
# Conclusion
#
# After thoroughly analyzing the TMDb dataset and answering questions through visualizations, below are key insights gotten in response to questions asked.
#
# The first question "How did the amount of produced films changed over time?" reveals that the amount of produced movies significantly increased from 1990 to 2011. The year 2011 had the highest released movies (168). While the initials years had the lowest(1).
#
# The second question "Which Month Released Highest Number Of Movies In all Of The Years?" reveals that more movies were released in the month of September (386). while the lowest amount of movies were released in January (192).
#
# The third question "What is the most and what is the least popular movie?" indicates that Minions is the most popular movie. Minions came out in June 2015 and it features Sandra Bullock, Jon Hamm, Michael Keaton, etc. While the least popular movie is Woman Thou Art Loosed. It was released in september 2004.
#
# The forth question "What are the 10 most and least profitable movies?" was answered using a pointplot line chart to show the top 10 and least 10 movies. Where movies like Avatar, Titanic, Jurassic World, Furious 7, The Avengers, Avengers: Age of Ultron earned the highest profits. While movies like The Lone Ranger, The Alamo, Mars Needs Moms, The 13th Warrior, The Adventures of Pluto Nash, Metropolis earned the least profits.
#
# The fifth question "What are the correlations between popularity, revenue, budget and profit?" was answered through visualizations. Scatter plots were used to show that there may be a relationship between revenue and profits of the movies as well as between the budget and profit.

# %% [markdown]
# Limitations:
#
# All results are limited as no advanced statistics were performed only exploratory analysis. The dataset in itself was limiting as many entries in the dataset were removed due to missing data. During the data cleaning process, colums such as budget, revenue and runtime had multiple zero values that had to be turned into NaN and dropped to prevent using wrong data. Also I had to join and split the data from two different csv files such as cast, genres, directors etc that were fetched from columns of multiple dictionaies into new columns. This increased the time taken in analyzing the dataset.
#
# I made use of some codes from stackoverflow.
